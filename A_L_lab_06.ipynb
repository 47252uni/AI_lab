# %% [markdown]
# <a href="https://colab.research.google.com/github/47252uni/AI_lab/blob/main/A_L_lab_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #name: sayed bashar sial
# #SAP: 47252
# #LAB_06

# %%
# initial state (4x4 puzzle)
puzzle = []

puzzle.append(1)
puzzle.append(2)
puzzle.append(3)
puzzle.append(4)

puzzle.append(5)
puzzle.append(6)
puzzle.append(7)
puzzle.append(8)

puzzle.append(9)
puzzle.append(10)
puzzle.append(11)
puzzle.append(12)

puzzle.append(13)
puzzle.append(15)
puzzle.append(14)
puzzle.append(0)

# goal state
goal = []

goal.append(1)
goal.append(2)
goal.append(3)
goal.append(4)

goal.append(5)
goal.append(6)
goal.append(7)
goal.append(8)

goal.append(9)
goal.append(10)
goal.append(11)
goal.append(12)

goal.append(13)
goal.append(14)
goal.append(15)
goal.append(0)

# %%
import heapq

graph = {
    'S': {'A': 1, 'B': 4},
    'A': {'C': 2, 'D': 5},
    'B': {'D': 1},
    'C': {'G': 7},
    'D': {'G': 3},
    'G': {}
}

heuristic = {
    'S': 7,
    'A': 6,
    'B': 2,
    'C': 1,
    'D': 1,
    'G': 0
}

def astar(start, goal):

    pq = []
    heapq.heappush(pq, (0, start, []))

    visited = set()

    while pq:

        cost, node, path = heapq.heappop(pq)

        if node in visited:
            continue

        path = path + [node]

        if node == goal:
            return path

        visited.add(node)

        for neighbor in graph[node]:
            new_cost = cost + graph[node][neighbor] + heuristic[neighbor]
            heapq.heappush(pq, (new_cost, neighbor, path))

path = astar('S','G')

print("Shortest Path:", path)
# Out:
# Shortest Path: ['S', 'B', 'D', 'G']

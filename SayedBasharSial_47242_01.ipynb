# %% [markdown]
# <a href="https://colab.research.google.com/github/47252uni/AI_lab/blob/main/SayedBasharSial_47242_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Sayed Bashar Sial
# # SAP_ID: 47242

# %%
# Arithmetic Operators

print("Arithmetic Operators")
a = 10
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Exponent:", a ** b)
print("Floor Division:", a // b)
# Out:
# Arithmetic Operators
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Modulus: 0
# Exponent: 100000
# Floor Division: 2

# %%
# Assignment Operators

print("\nAssignment Operators")
x = 10
print("Initial value:", x)

x += 5
print("After += 5:", x)

x -= 3
print("After -= 3:", x)

x *= 2
print("After *= 2:", x)

x /= 4
print("After /= 4:", x)
# Out:
# Assignment Operators
# Initial value: 10
# After += 5: 15
# After -= 3: 12
# After *= 2: 24
# After /= 4: 6.0

# %%
# Comparison Operators

print("\nComparison Operators")
a = 10
b = 5

print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a < b:", a < b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)
# Out:
# Comparison Operators
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False

# %%
# Logical Operators

print("\nLogical Operators")

x = True
y = False

print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)
# Out:
# Logical Operators
# x and y: False
# x or y: True
# not x: False
